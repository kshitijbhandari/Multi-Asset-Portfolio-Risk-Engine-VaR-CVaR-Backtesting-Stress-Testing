# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from scipy.stats import norm, chi2
from arch import arch_model

sns.set_theme(style="darkgrid")

with open("portfolio_data.pkl", "rb") as f:
    data = pickle.load(f)

portfolio_returns = data["portfolio_returns"]
conf_levels       = data["conf_levels"]
lookback          = data["lookback"]

# Phase 4 rolling VaR results for direct comparison
all_bt     = data["backtest_all_results"]
kup_99     = data["kupiec_results_99"]
chris_99   = data["christoffersen_99"]

returns = portfolio_returns.values
dates   = portfolio_returns.index

print("Loaded successfully.")
print(f"Observations : {len(returns)}")
print(f"Date range   : {dates[0].date()} → {dates[-1].date()}")
# Out:
# Loaded successfully.
# Observations : 2514
# Date range   : 2015-01-05 → 2024-12-30

# %%
import os

_cwd = os.getcwd()
_proj_root = _cwd if os.path.exists(os.path.join(_cwd, "README.md")) else os.path.dirname(_cwd)
RESULTS = os.path.join(_proj_root, "results", "phase_7_garch")
os.makedirs(RESULTS, exist_ok=True)
print(f"Results folder: {RESULTS}")
# Out:
# Results folder: c:\Users\kshit\VaR CVaR\results\phase_7_garch

# %%
# arch_model expects returns in percentage terms (multiply by 100)
# rescaled_vol = actual_vol * 100, VaR rescaled back at the end
returns_pct = returns * 100

am = arch_model(
    returns_pct,
    vol="Garch",   # GARCH variance process
    p=1,           # lag order for ARCH term (ε²_{t-1})
    q=1,           # lag order for GARCH term (σ²_{t-1})
    mean="Zero",   # μ = 0 (same conservative assumption as Phase 2)
    dist="normal", # normal innovations — we'll compare to Student-t later
)

res = am.fit(disp="off")   # disp="off" suppresses optimiser output
print(res.summary())

omega = res.params["omega"]
alpha = res.params["alpha[1]"]
beta  = res.params["beta[1]"]

print(f"\n── Estimated Parameters ──────────────────────────────")
print(f"  ω (long-run baseline)  : {omega:.6f}")
print(f"  α (shock reaction)     : {alpha:.4f}")
print(f"  β (vol persistence)    : {beta:.4f}")
print(f"  α + β                  : {alpha + beta:.4f}  (must be < 1 for stationarity)")
print(f"  Long-run daily vol     : {np.sqrt(omega / (1 - alpha - beta)):.4f}%")

# What to look for:
# α + β close to 1 → high volatility persistence (typical for equity returns)
# Large β → today's vol is mostly yesterday's vol
# Large α → vol reacts strongly to shocks
# Out:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2244.55
# Distribution:                  Normal   AIC:                           4495.10
# Method:            Maximum Likelihood   BIC:                           4512.59
#                                         No. Observations:                 2514
# Date:                Tue, Mar 31 2026   Df Residuals:                     2514
# Time:                        22:58:51   Df Model:                            0
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      7.0954e-03  2.894e-03      2.452  1.421e-02 [1.424e-03,1.277e-02]
# alpha[1]       0.1127  2.174e-02      5.182  2.191e-07   [7.005e-02,  0.155]
# beta[1]        0.8764  2.342e-02     37.421 1.748e-306     [  0.830,  0.922]
# ============================================================================
#
# Covariance estimator: robust
#
# ── Estimated Parameters ──────────────────────────────
#   ω (long-run baseline)  : 0.007095
#   α (shock reaction)     : 0.1127
#   β (vol persistence)    : 0.8764
#   α + β                  : 0.9890  (must be < 1 for stationarity)
#   Long-run daily vol     : 0.8040%

# %%
cond_vol = res.conditional_volatility

fig, axes = plt.subplots(2, 1, figsize=(15, 7), sharex=True)

axes[0].fill_between(dates, returns * 100, 0,
                     where=(returns >= 0), color="steelblue", alpha=0.6, label="Gain")
axes[0].fill_between(dates, returns * 100, 0,
                     where=(returns < 0),  color="tomato",    alpha=0.6, label="Loss")
axes[0].set_ylabel("Daily Return (%)")
axes[0].set_title("Portfolio Daily Returns")
axes[0].legend(fontsize=8)

axes[1].plot(dates, cond_vol, color="darkorange", linewidth=1.0,
             label="GARCH(1,1) Conditional Vol")
axes[1].set_ylabel("Conditional Volatility (%)")
axes[1].set_title("GARCH(1,1) Conditional Volatility — Spikes During Stress Periods")
axes[1].legend(fontsize=8)

plt.tight_layout()
plt.savefig(os.path.join(RESULTS, "01_garch_conditional_volatility.png"), dpi=150, bbox_inches="tight")
plt.show()

print(f"\nConditional Vol stats:")
print(f"  Min  : {cond_vol.min():.4f}%  (calmest day)")
print(f"  Max  : {cond_vol.max():.4f}%  (most volatile day)")
print(f"  Mean : {cond_vol.mean():.4f}%")
# Out:
# Conditional Vol stats:
#   Min  : 0.2910%  (calmest day)
#   Max  : 4.2396%  (most volatile day)
#   Mean : 0.6474%

# %%
def rolling_garch_var(
    returns: np.ndarray,
    lookback: int,
    confidence: float,
) -> np.ndarray:
    """
    Rolling GARCH(1,1) VaR.
    On each day t, fits GARCH on returns[t-lookback:t],
    takes the 1-step-ahead conditional vol forecast,
    and computes VaR = -z_c * σ_forecast.
    Returns VaR as a POSITIVE array (loss convention), NaN before warmup.
    """
    n   = len(returns)
    var = np.full(n, np.nan)
    z   = norm.ppf(1 - confidence)   # negative number

    for t in range(lookback, n):
        window = returns[t - lookback : t] * 100   # % terms for arch

        try:
            am  = arch_model(window, vol="Garch", p=1, q=1,
                             mean="Zero", dist="normal")
            res = am.fit(disp="off", show_warning=False)

            fc       = res.forecast(horizon=1, reindex=False)
            sigma_t  = np.sqrt(fc.variance.values[-1, 0])   
            sigma_t /= 100                                  

            var[t] = -z * sigma_t  

        except Exception:
            sigma_fb = window.std() / 100
            var[t]   = -z * sigma_fb

    return var


print("Computing rolling GARCH VaR — this will take a few minutes...")
print("(Refitting GARCH 2,262 times on 252-day windows)\n")

garch_var_99 = rolling_garch_var(returns, lookback, 0.99)
garch_var_95 = rolling_garch_var(returns, lookback, 0.95)

print("Done.")
valid = ~np.isnan(garch_var_99)
print(f"\nGARCH 99% VaR — rolling stats (post-warmup):")
print(f"  Min  : {garch_var_99[valid].min()*100:.4f}%")
print(f"  Max  : {garch_var_99[valid].max()*100:.4f}%  ← spikes during crises")
print(f"  Mean : {garch_var_99[valid].mean()*100:.4f}%")
# Out:
# Computing rolling GARCH VaR — this will take a few minutes...
# (Refitting GARCH 2,262 times on 252-day windows)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09749. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09745. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09596. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09473. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09292. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09277. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09177. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09129. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09065. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09064. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09041. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08946. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08983. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09067. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08936. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08693. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08684. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0831. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08322. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08325. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08301. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08219. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07543. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07592. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07608. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07814. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07851. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0786. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07864. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07862. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07871. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07819. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0787. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07804. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07744. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07732. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07818. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07839. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07886. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07949. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07954. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0793. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07931. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07777. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07835. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07907. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07909. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0791. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08215. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08385. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08461. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08467. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09933. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09749. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09745. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09596. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09473. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09292. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09277. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09177. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09129. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09065. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09064. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09041. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08946. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08983. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09067. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08936. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08693. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08684. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0831. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08322. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08325. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08301. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08219. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07543. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07592. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07608. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07814. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07851. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0786. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07864. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07862. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07871. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07819. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0787. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07804. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07744. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07732. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07818. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07839. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07886. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07949. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07954. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0793. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07931. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07777. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07835. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07907. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07909. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0791. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08215. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08385. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08461. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08467. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09933. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# Done.
#
# GARCH 99% VaR — rolling stats (post-warmup):
#   Min  : 0.5407%
#   Max  : 12.2714%  ← spikes during crises
#   Mean : 1.5049%

# %%
def get_exceptions(returns, rolling_var):
    exc = np.zeros(len(returns), dtype=int)
    valid = ~np.isnan(rolling_var)
    exc[valid] = (returns[valid] < -rolling_var[valid]).astype(int)
    return exc

def kupiec_test(exceptions, confidence, lookback):
    exc    = exceptions[lookback:]
    T, N   = len(exc), exc.sum()
    p_hat  = N / T
    p_star = 1 - confidence
    if N == 0 or N == T:
        return {"N": N, "T": T, "p_hat": p_hat, "LR_uc": np.nan,
                "p_value": np.nan, "reject": True}
    LR_uc = -2 * (
        np.log((1 - p_star) ** (T - N) * p_star ** N)
        - np.log((1 - p_hat) ** (T - N) * p_hat ** N)
    )
    p_value = 1 - chi2.cdf(LR_uc, df=1)
    return {"N": N, "T": T, "p_hat": p_hat, "LR_uc": LR_uc,
            "p_value": p_value, "reject": p_value < 0.05}

def christoffersen_test(exceptions, confidence, lookback):
    exc = exceptions[lookback:].astype(int)
    T   = len(exc)
    n00 = n01 = n10 = n11 = 0
    for t in range(1, T):
        prev, curr = exc[t-1], exc[t]
        if   prev == 0 and curr == 0: n00 += 1
        elif prev == 0 and curr == 1: n01 += 1
        elif prev == 1 and curr == 0: n10 += 1
        elif prev == 1 and curr == 1: n11 += 1
    pi01 = n01 / (n00 + n01) if (n00 + n01) > 0 else 0
    pi11 = n11 / (n10 + n11) if (n10 + n11) > 0 else 0
    pi   = (n01 + n11) / T
    eps  = 1e-10
    LR_ind = -2 * (
        np.log(pi + eps) * (n01 + n11) + np.log(1 - pi + eps) * (n00 + n10)
        - np.log(pi01 + eps) * n01 - np.log(1 - pi01 + eps) * n00
        - np.log(pi11 + eps) * n11 - np.log(1 - pi11 + eps) * n10
    )
    LR_ind  = max(LR_ind, 0)
    k       = kupiec_test(exceptions, confidence, lookback)
    LR_uc   = k["LR_uc"] if not np.isnan(k["LR_uc"]) else 0
    LR_cc   = LR_uc + LR_ind
    p_cc    = 1 - chi2.cdf(LR_cc, df=2)
    return {"n00": n00, "n01": n01, "n10": n10, "n11": n11,
            "pi01": pi01, "pi11": pi11,
            "LR_cc": LR_cc, "p_value_cc": p_cc, "reject_cc": p_cc < 0.05}

# ── Run backtests ──
exc_garch_99 = get_exceptions(returns, garch_var_99)
exc_garch_95 = get_exceptions(returns, garch_var_95)

for conf, exc_g in [(0.99, exc_garch_99), (0.95, exc_garch_95)]:
    k  = kupiec_test(exc_g, conf, lookback)
    cr = christoffersen_test(exc_g, conf, lookback)
    print(f"── GARCH {int(conf*100)}% VaR ────────────────────────────────")
    print(f"  Exceptions : {k['N']} / {k['T']}  ({k['p_hat']:.3%})  expected {(1-conf):.1%}")
    print(f"  π01        : {cr['pi01']:.4f}")
    print(f"  π11        : {cr['pi11']:.4f}  (Phase 4 HS was 0.1429)")
    print(f"  Kupiec     : {'PASS ✓' if not k['reject'] else 'FAIL ✗'}  (p={k['p_value']:.4f})")
    print(f"  Christoff  : {'PASS ✓' if not cr['reject_cc'] else 'FAIL ✗'}  (p={cr['p_value_cc']:.4f})")
    print()
# Out:
# ── GARCH 99% VaR ────────────────────────────────
#   Exceptions : 43 / 2262  (1.901%)  expected 1.0%
#   π01        : 0.0185
#   π11        : 0.0465  (Phase 4 HS was 0.1429)
#   Kupiec     : FAIL ✗  (p=0.0001)
#   Christoff  : FAIL ✗  (p=0.0003)
#
# ── GARCH 95% VaR ────────────────────────────────
#   Exceptions : 114 / 2262  (5.040%)  expected 5.0%
#   π01        : 0.0489
#   π11        : 0.0789  (Phase 4 HS was 0.1429)
#   Kupiec     : PASS ✓  (p=0.9309)
#   Christoff  : PASS ✓  (p=0.4113)

# %%
from scipy.stats import t as student_t

# First fit Student-t GARCH on full sample to inspect ν
am_t = arch_model(
    returns_pct,
    vol="Garch", p=1, q=1,
    mean="Zero",
    dist="t",    
)
res_t = am_t.fit(disp="off")

nu    = res_t.params["nu"]         # estimated degrees of freedom
omega_t = res_t.params["omega"]
alpha_t = res_t.params["alpha[1]"]
beta_t  = res_t.params["beta[1]"]

print(f"── GARCH(1,1)-t Parameters ───────────────────────────")
print(f"  ω = {omega_t:.6f}  α = {alpha_t:.4f}  β = {beta_t:.4f}  α+β = {alpha_t+beta_t:.4f}")
print(f"  ν (degrees of freedom) = {nu:.4f}")
print(f"\n  Normal 99% z  : {norm.ppf(0.01):.4f}  (thinner tail)")
print(f"  Student-t 99% z (ν={nu:.1f}): {student_t.ppf(0.01, df=nu):.4f}  (fatter tail)")
print(f"\n  → t-quantile is {abs(student_t.ppf(0.01,df=nu)/norm.ppf(0.01)):.3f}x more conservative than normal")
print(f"\n  Low ν (< 10) confirms fat tails in the data — normal assumption was wrong.")
# Out:
# ── GARCH(1,1)-t Parameters ───────────────────────────
#   ω = 0.005013  α = 0.1015  β = 0.8922  α+β = 0.9937
#   ν (degrees of freedom) = 7.3870
#
#   Normal 99% z  : -2.3263  (thinner tail)
#   Student-t 99% z (ν=7.4): -2.9547  (fatter tail)
#
#   → t-quantile is 1.270x more conservative than normal
#
#   Low ν (< 10) confirms fat tails in the data — normal assumption was wrong.

# %%
def rolling_garch_t_var(
    returns: np.ndarray,
    lookback: int,
    confidence: float,
) -> np.ndarray:
    """
    Rolling GARCH(1,1) VaR with Student-t innovations.
    On each window: fits GARCH-t, estimates ν, gets σ_forecast,
    then VaR = -t_ν(1-c) * σ_forecast.
    """
    n   = len(returns)
    var = np.full(n, np.nan)

    for t in range(lookback, n):
        window = returns[t - lookback : t] * 100

        try:
            am  = arch_model(window, vol="Garch", p=1, q=1,
                             mean="Zero", dist="t")
            res = am.fit(disp="off", show_warning=False)

            nu_t     = res.params["nu"]
            fc       = res.forecast(horizon=1, reindex=False)
            sigma_t  = np.sqrt(fc.variance.values[-1, 0]) / 100

            # Student-t quantile (negative number, fatter tail than normal)
            z_t      = student_t.ppf(1 - confidence, df=nu_t)
            var[t]   = -z_t * sigma_t

        except Exception:
            # Fallback to normal GARCH if t fails
            try:
                am  = arch_model(window, vol="Garch", p=1, q=1,
                                 mean="Zero", dist="normal")
                res = am.fit(disp="off", show_warning=False)
                fc       = res.forecast(horizon=1, reindex=False)
                sigma_t  = np.sqrt(fc.variance.values[-1, 0]) / 100
                var[t]   = -norm.ppf(1 - confidence) * sigma_t
            except Exception:
                sigma_fb = window.std() / 100
                var[t]   = -norm.ppf(1 - confidence) * sigma_fb

    return var


print("Computing rolling GARCH-t VaR — this will take a few minutes...")
garch_t_var_99 = rolling_garch_t_var(returns, lookback, 0.99)
garch_t_var_95 = rolling_garch_t_var(returns, lookback, 0.95)
print("Done.")
# Out:
# Computing rolling GARCH-t VaR — this will take a few minutes...
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09749. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09745. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09596. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09473. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09292. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09277. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09177. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09129. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09065. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09064. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09041. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08946. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08983. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09067. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08936. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08693. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08684. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0831. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08322. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08325. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08301. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08219. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07543. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07592. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07608. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07814. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07851. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0786. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07864. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07862. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07871. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07819. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0787. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07804. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07744. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07732. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07818. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07839. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07886. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07949. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07954. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0793. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07931. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07777. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07835. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07907. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07909. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0791. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08215. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08385. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08461. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08467. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09933. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09749. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09745. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09596. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09473. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09292. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09277. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09177. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09129. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09065. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09064. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09041. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08946. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08983. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09067. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08936. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08699. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08693. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08684. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0831. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08322. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08325. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08301. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08219. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07543. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07592. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07608. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07814. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07851. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0786. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07864. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07862. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07871. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07819. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0787. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07804. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07744. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07732. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07818. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07839. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07886. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07949. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07954. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0793. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07931. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07777. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07835. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07907. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07909. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0791. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08215. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08385. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08461. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08467. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# c:\Users\kshit\VaR CVaR\.venv\Lib\site-packages\arch\univariate\base.py:694: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09933. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   self._check_scale(resids)
# Done.

# %%
exc_garch_t_99 = get_exceptions(returns, garch_t_var_99)
exc_garch_t_95 = get_exceptions(returns, garch_t_var_95)

T = len(returns) - lookback   

rows = []

for name, key in [("Hist Sim (Ph4)", "HS"), ("Parametric (Ph4)", "Parametric"), ("MC (Ph4)", "MC")]:
    k  = kup_99[key]
    cr = chris_99[key]
    rows.append({
        "Method":     name,
        "Exceptions": k["N"],
        "Act. Rate":  f"{k['p_hat']:.3%}",
        "π11":        f"{cr['pi11']:.4f}",
        "Kupiec":     "PASS ✓" if not k["reject"]    else "FAIL ✗",
        "Christoff":  "PASS ✓" if not cr["reject_cc"] else "FAIL ✗",
    })

for name, exc in [("GARCH-Normal", exc_garch_99), ("GARCH-t  ←", exc_garch_t_99)]:
    k  = kupiec_test(exc, 0.99, lookback)
    cr = christoffersen_test(exc, 0.99, lookback)
    rows.append({
        "Method":     name,
        "Exceptions": k["N"],
        "Act. Rate":  f"{k['p_hat']:.3%}",
        "π11":        f"{cr['pi11']:.4f}",
        "Kupiec":     "PASS ✓" if not k["reject"]    else "FAIL ✗",
        "Christoff":  "PASS ✓" if not cr["reject_cc"] else "FAIL ✗",
    })

df = pd.DataFrame(rows).set_index("Method")
print(f"── 99% VaR Full Comparison (T={T}, expected={0.01*T:.1f}) ─────────")
print(df.to_string())
# Out:
# ── 99% VaR Full Comparison (T=2262, expected=22.6) ─────────
#                   Exceptions Act. Rate     π11  Kupiec Christoff
# Method
# Hist Sim (Ph4)            35    1.547%  0.1429  FAIL ✗    FAIL ✗
# Parametric (Ph4)          50    2.210%  0.1200  FAIL ✗    FAIL ✗
# MC (Ph4)                  49    2.166%  0.0816  FAIL ✗    FAIL ✗
# GARCH-Normal              43    1.901%  0.0465  FAIL ✗    FAIL ✗
# GARCH-t  ←                24    1.061%  0.0417  PASS ✓    PASS ✓

# %%
valid_dates  = dates[lookback:]
actual_valid = returns[lookback:] * 100
roll_hs_99   = all_bt[0.99]["roll_hs"]

fig, ax = plt.subplots(figsize=(15, 6))

ax.plot(valid_dates, actual_valid, color="grey", linewidth=0.5, alpha=0.6,
        label="Actual return")
ax.plot(valid_dates, -roll_hs_99[lookback:] * 100,
        color="steelblue", linewidth=1.0, alpha=0.8, label="HS (Ph4)")
ax.plot(valid_dates, -garch_var_99[lookback:] * 100,
        color="darkorange", linewidth=1.0, alpha=0.8, label="GARCH-Normal")
ax.plot(valid_dates, -garch_t_var_99[lookback:] * 100,
        color="tomato", linewidth=1.2, label="GARCH-t")

ax.axhline(0, color="black", linewidth=0.5)
ax.set_ylabel("Return / VaR (%)")
ax.set_title("99% VaR: Static HS vs GARCH-Normal vs GARCH-t")
ax.legend(fontsize=9)
plt.tight_layout()
plt.savefig(os.path.join(RESULTS, "02_var_model_comparison.png"), dpi=150, bbox_inches="tight")
plt.show()

data.update({
    "garch_t_var_99": garch_t_var_99,
    "garch_t_var_95": garch_t_var_95,
    "exc_garch_t_99": exc_garch_t_99,
    "exc_garch_t_95": exc_garch_t_95,
    "garch_t_params": {"omega": omega_t, "alpha": alpha_t,
                       "beta": beta_t,   "nu": nu},
})
with open("portfolio_data.pkl", "wb") as f:
    pickle.dump(data, f)
print("Saved GARCH-t results to portfolio_data.pkl")
# Out:
# Saved GARCH-t results to portfolio_data.pkl

# %%
valid_dates  = dates[lookback:]
actual_valid = returns[lookback:] * 100
roll_hs_99   = all_bt[0.99]["roll_hs"]
exc_hs_99    = all_bt[0.99]["exc_hs"]

fig, axes = plt.subplots(3, 1, figsize=(15, 13), sharex=True)

configs = [
    ("Historical Simulation 99% VaR — Static Window (Phase 4 baseline)",
     roll_hs_99,     exc_hs_99,     "steelblue"),
    ("GARCH(1,1)-Normal 99% VaR — Dynamic Vol, Normal Tail",
     garch_var_99,   exc_garch_99,  "darkorange"),
    ("GARCH(1,1)-t 99% VaR — Dynamic Vol + Fat Tails  [PASSES both tests]",
     garch_t_var_99, exc_garch_t_99,"tomato"),
]

for ax, (title, var_series, exc_series, color) in zip(axes, configs):
    exc_mask = exc_series[lookback:] == 1
    ax.plot(valid_dates, actual_valid, color="grey", linewidth=0.5, alpha=0.7,
            label="Actual return")
    ax.plot(valid_dates, -var_series[lookback:] * 100, color=color,
            linewidth=1.2, label=f"99% VaR")
    ax.scatter(valid_dates[exc_mask], actual_valid[exc_mask],
               color="red", s=12, zorder=5, label=f"Exceptions ({exc_mask.sum()})")
    ax.axhline(0, color="black", linewidth=0.5)
    ax.set_ylabel("Return (%)")
    ax.set_title(title)
    ax.legend(fontsize=8, loc="lower right")

plt.suptitle("Rolling 99% VaR: Static HS vs GARCH-Normal vs GARCH-t",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS, "03_hs_vs_garch_normal_vs_garch_t.png"), dpi=150, bbox_inches="tight")
plt.show()
